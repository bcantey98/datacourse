# %% [markdown]
# ### Exercise 1
# Ask a user for 5 names and place each one in to a list called <i>names</i>. Then, print <i>names</i>.

# %%
n1 = input("Please Enter a Name: ")
n2 = input("Please Enter a Name: ")
n3 = input("Please Enter a Name: ")
n4 = input("Please Enter a Name: ")
n5 = input("Please Enter a Name: ")

names = [n1,n2,n3,n4,n5]
print(names)
# Out:
# Please Enter a Name: John
# Please Enter a Name: Brandon
# Please Enter a Name: Twon
# Please Enter a Name: Bryce
# Please Enter a Name: Chop
# ['John', 'Brandon', 'Twon', 'Bryce', 'Chop']

# %% [markdown]
# ### Exercise 2
# Print out a randomly selected name in the names list.

# %%
import random as rd
rd.choice(names)
# Out:
# 'Bryce'

# %% [markdown]
# ### Exercise 3
#
# Ask a user for a specific color and store that value into a variable. If the answer is gray, print "You found Victor's favorite color!". If the answer is anything besides gray, print "[color name] is not Victor's favorite color."

# %%
color = input("Please enter a color: ")

if color == "gray" or color == "Gray":
  print("You found Victor's favorite color!")
else:
  print(f"{color} is not Victor's favorite color.")
# Out:
# Please enter a color: brown
# brown is not Victor's favorite color.

# %% [markdown]
# ### Exercise 4
# Ask for an exam score and store that number. If the number is greater than 100, then print out 'You cannot have an exam score higher than 100'. If the number doesn't exceeed 100 but is greater than or equal to 75, then print out 'You did great on your exam!'. Otherwise if they scored lower than 75, then print out 'You need to study harder'.

# %%
score = int(input("What was your exam score: "))

if score > 100:
  print("You cannot have an exam score higher than 100")
elif score <= 100 and score >= 75:
  print("You did great on your exam")
else:
  print("You need to study harder")
# Out:
# What was your exam score: 123
# You cannot have an exam score higher than 100

# %% [markdown]
# ### Exercise 5
# Write a function to convert a test score to a grade where
#  - 90 - 100: A
#  - 80 - 89:  B
#  - 70 - 79:  C
#  - 60 - 69:  D
#  - < 60   :  F
#
# If a score is not between 0 and 100 then print out an error message. In the program, ask the user for a score and then call your function.

# %%
grade = int(input("Please enter your test score: "))

if grade >= 90 and grade <= 100:
  print("A")
elif grade >= 80 and grade <= 89:
  print("B")
elif grade >= 70 and grade <= 79:
  print("C")
elif grade >= 60 and grade <= 69:
  print("D")
elif grade <= 60:
  print("F")
elif grade < 0 and grade > 100:
  print("Please enter a valid test score")
# Out:
# Please enter your test score: 99
# A
